# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshmuley/Computer-vision-project/blob/main/Apple_Detection_and_Counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

from ultralytics import YOLO
from ultralytics.solutions import object_counter
import cv2

model = YOLO("yolov8n.pt")
cap = cv2.VideoCapture("/content/apple_red.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Define region points
region_points = [(20, 400), (1080, 404), (1080, 360), (20, 360)]

# Video writer
video_writer = cv2.VideoWriter("object_counting_output.avi",
                       cv2.VideoWriter_fourcc(*'mp4v'),
                       fps,
                       (w, h))

# Init Object Counter
counter = object_counter.ObjectCounter()
counter.set_args(view_img=True,
                 reg_pts=region_points,
                 classes_names=model.names,
                 draw_tracks=True)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False)

    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.0/705.0 kB 7.3 MB/s eta 0:00:00
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 25.0MB/s]
# Streaming output truncated to the last 5000 lines.
#
# 0: 640x384 2 apples, 148.0ms
# Speed: 3.4ms preprocess, 148.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 apples, 148.1ms
# Speed: 7.3ms preprocess, 148.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 apples, 153.5ms
# Speed: 6.0ms preprocess, 153.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 apples, 161.8ms
# Speed: 5.7ms preprocess, 161.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 apples, 230.3ms
# Speed: 7.6ms preprocess, 230.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 apples, 231.7ms
# Speed: 5.6ms preprocess, 231.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# ...
